# %% [markdown]
# # Miles Per Gallon
#
# There are many different features of a car that can help determine how many miles per gallon it has. In this activity, we will be creating a scatterplot to chart some of these relationships.
#
# * The scatterplot that we want to create will compare 'mpg' to 'horsepower'. A reference image can be found at the bottom of this notebook, but how we go about creating this chart is completely up to you!
#
#     * When reading in the data, there are 6 rows that are missing values in 'horsepower'. It is up to you to figure out what the author put in their place and drop the rows.

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

filepath = os.path.join("mpg.csv")

mpg_df = pd.read_csv(filepath)
mpg_df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
#Cleaning the data
print(mpg_df['horsepower'].value_counts())

mpg_df.drop(mpg_df[mpg_df.horsepower == '?'].index, inplace=True)

print('-'*30)

print(mpg_df['horsepower'].value_counts())
# Out:
# 150    22
# 90     20
# 88     19
# 110    18
# 100    17
# 95     14
# 75     14
# 67     12
# 70     12
# 105    12
# 65     10
# 97      9
# 85      9
# 140     7
# 80      7
# 145     7
# 78      6
# 68      6
# 84      6
# 92      6
# 72      6
# ?       6
# 60      5
# 170     5
# 130     5
# 86      5
# 71      5
# 180     5
# 115     5
# 175     5
#        ..
# 64      1
# 93      1
# 167     1
# 142     1
# 94      1
# 132     1
# 82      1
# 193     1
# 89      1
# 116     1
# 61      1
# 135     1
# 66      1
# 200     1
# 49      1
# 138     1
# 137     1
# 107     1
# 91      1
# 208     1
# 102     1
# 133     1
# 149     1
# 148     1
# 108     1
# 230     1
# 77      1
# 220     1
# 54      1
# 113     1
# Name: horsepower, Length: 94, dtype: int64
# ------------------------------
# 150    22
# 90     20
# 88     19
# 110    18
# 100    17
# 95     14
# 75     14
# 105    12
# 70     12
# 67     12
# 65     10
# 97      9
# 85      9
# 145     7
# 140     7
# 80      7
# 78      6
# 84      6
# 68      6
# 92      6
# 72      6
# 115     5
# 130     5
# 180     5
# 170     5
# 71      5
# 175     5
# 86      5
# 60      5
# 83      4
#        ..
# 135     1
# 103     1
# 64      1
# 210     1
# 158     1
# 94      1
# 132     1
# 91      1
# 193     1
# 89      1
# 116     1
# 61      1
# 66      1
# 200     1
# 49      1
# 138     1
# 137     1
# 82      1
# 107     1
# 208     1
# 102     1
# 133     1
# 149     1
# 148     1
# 108     1
# 230     1
# 77      1
# 220     1
# 54      1
# 113     1
# Name: horsepower, Length: 93, dtype: int64

# %%
print(mpg_df.dtypes)

mpg_df['horsepower'] = pd.to_numeric(mpg_df['horsepower'])

mpg_df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower        int64
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
#Preparing the limits and data
x_limit = mpg_df['mpg'].max + 10
x_axis = np.arange(0, x_limit, 1)

y_limit = mpg_df['horsepower'].max + 10
y_axis = np.arange(0, y_limit, 1)

# Tells matplotlib that we want to make a scatter plot
# The size of each point on our plot is determined by their x value

mpg_df.plot(x="mpg", y="horsepower", kind="scatter")


plt.scatter(mpg_df['mpg'], mpg_df['horsepower'], marker="o", facecolors="red", edgecolors="black",
            s=mpg_df['mpg'], alpha=0.75)
